# %% [markdown]
# # Regression analysis
# Regression models are used to predict target variables on a continuous scale.

# %% [markdown]
# ## Simple Linear Regression
#
# The goal of simple (univariate) linear regression is to model the relationship between a single feature (explanatory variable, x) and a continuous-valued target (responsevariable, y). The equation of a linear model with one explanatory variable is defined as follows:
#
# y = W0 + W1X
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Multiple Linear Regression
#
# modelling the relationship between a multiple features (explanatory variables, x) and  continuous-valued targets (response variable, y); this process is called multiple linear regression:
#
# **$y =  $W0X0 + W1X1 + ... + WmXm = ∑WiXi = X.dot(W.transpose)**

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

sns.set_style()

# %%
file = '../data/boston housing/'

# %%
df = pd.read_csv(file, header=None, sep='\s+')
df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

df.head()

# %% [markdown]
# ### Exloratory data analyiss
